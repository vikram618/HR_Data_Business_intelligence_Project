# %%
import sys
# !{sys.executable} -m pip install fg-data-profiling

# %%
import pandas as pd
import os
from data_profiling import ProfileReport

# All files with their names
files = {
    "HR_Dataset_Report":        r"C:\Users\vikra\Downloads\HR Analytics Project\HR_Analytics_dirty.csv",
    
}

# Create reports folder
os.makedirs(r"C:\Users\vikra\Downloads\HR Analytics Project", exist_ok=True)

# Loop through each file and generate report
for name, path in files.items():
    print(f"Processing {name}...")
    df = pd.read_csv(path, low_memory=False, encoding='latin1')
    profile = ProfileReport(df, title=f"{name} Profile", minimal=True)
    profile.to_file(rf"C:\Users\vikra\Downloads\HR Analytics Project\reports\{name}_profile.html")
    print(f"✅ {name} report saved!\n")

print("REPORT GENERATED!")
# Out:
# Processing HR_Dataset_Report...
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ HR_Dataset_Report report saved!
#
# REPORT GENERATED!
